# %% [markdown]
# # **Training mBART-50 model for Russian to Chukchi translation**

# %%
# !pip install -U datasets==2.14.4
# Out:
# Requirement already satisfied: datasets==2.14.4 in /usr/local/lib/python3.11/dist-packages (2.14.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.4) (2.0.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.4) (18.1.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.4) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.4) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.4) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.4) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.4) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.4) (0.70.15)
# Requirement already satisfied: fsspec>=2021.11.1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.11.1->datasets==2.14.4) (2025.3.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.4) (3.11.15)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.4) (0.32.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.4) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.4) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==2.14.4) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==2.14.4) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==2.14.4) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==2.14.4) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==2.14.4) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==2.14.4) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==2.14.4) (1.20.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets==2.14.4) (3.18.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets==2.14.4) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets==2.14.4) (1.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets==2.14.4) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets==2.14.4) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets==2.14.4) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets==2.14.4) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets==2.14.4) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets==2.14.4) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets==2.14.4) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==2.14.4) (1.17.0)

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
import pandas as pd
from datasets import Dataset
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, MBartForConditionalGeneration
from transformers import DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer, TrainerCallback
import torch
import os
from google.colab import drive
import shutil
from transformers import TrainerCallbac

# %%
from transformers import set_seed
set_seed(42)

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DRIVE_PATH = "/content/drive/MyDrive/mbart_rus_ckt_checkpoints"
LOCAL_PATH = "/content/mbart_rus_ckt_checkpoints"

os.makedirs(DRIVE_PATH, exist_ok=True)
os.makedirs(LOCAL_PATH, exist_ok=True)

# %% [markdown]
# ## **Preparing Data**

# %%
# Loading data from CSV file
data_path = '/content/ckt-ru_filtered.csv'
df = pd.read_csv(data_path, delimiter=';')

# %%
# Splitting data into training and validation sets (1% for validation)
val_size = int(len(df) * 0.01)
train_df = df[:-val_size]
val_df = df[-val_size:]

# %%
# Creating different prompt variations for training data
def create_prompts(data, start_idx, end_idx):
    data_part = data.iloc[start_idx:end_idx]

    prompts = pd.DataFrame()
    prompts['rus_text'] = [
        f'Переведи это предложение с русского на чукотский: "{row["ru"]}"'
        for _, row in data_part.iterrows()
    ]
    prompts['ckt_text'] = [
        f'Вот перевод на чукотский: "{row["ckt"]}"'
        for _, row in data_part.iterrows()
    ]

    return prompts

# %%
# Creating training dataset with different prompt variations
train_parts = []
for i in range(0, len(train_df), len(train_df)//5):
    part = create_prompts(train_df, i, i + len(train_df)//5)
    train_parts.append(part)

# %%
train_data = pd.concat(train_parts)
train_dataset = Dataset.from_pandas(train_data)

# %%
# Creating validation dataset
val_prompts = create_prompts(val_df, 0, len(val_df))
val_dataset = Dataset.from_pandas(val_prompts)

# %%
# Loading model and tokenizer
model_ckpt = "facebook/mbart-large-50"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
model = MBartForConditionalGeneration.from_pretrained(model_ckpt).to("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/531 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/649 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.44G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.44G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/261 [00:00<?, ?B/s]

# %%
# Check if there's a checkpoint to resume training from
last_checkpoint = None
if os.path.exists(DRIVE_PATH):
    checkpoints = [d for d in os.listdir(DRIVE_PATH) if d.startswith("checkpoint-")]
    if checkpoints:
        last_checkpoint = os.path.join(DRIVE_PATH, sorted(checkpoints)[-1])
        print(f"Found checkpoint to resume from: {last_checkpoint}")

if last_checkpoint:
    model = MBartForConditionalGeneration.from_pretrained(last_checkpoint).to("cuda" if torch.cuda.is_available() else "cpu")
else:
    model = MBartForConditionalGeneration.from_pretrained(model_ckpt).to("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Function for converting text to tokens
def convert_examples_to_features(example_batch):
    input_encodings = tokenizer(
        example_batch["rus_text"],
        max_length=1024,
        padding="max_length",
        truncation=True
    )
    target_encodings = tokenizer(
        example_batch["ckt_text"],
        max_length=1024,
        padding="max_length",
        truncation=True
    )
    return {
        "input_ids": input_encodings["input_ids"],
        "attention_mask": input_encodings["attention_mask"],
        "labels": target_encodings["input_ids"]
    }

# %%
# Converting data
train_dataset_tf = train_dataset.map(convert_examples_to_features, batched=True, remove_columns=["rus_text", "ckt_text"])
val_dataset_tf = val_dataset.map(convert_examples_to_features, batched=True, remove_columns=["rus_text", "ckt_text"])
# Out:
# Map:   0%|          | 0/66586 [00:00<?, ? examples/s]
# Map:   0%|          | 0/672 [00:00<?, ? examples/s]

# %% [markdown]
# ## **Saving dataset to Google Drive**

# %%
from datasets import load_from_disk

# Paths for saving mapped datasets
TRAIN_DATASET_PATH = "/content/drive/MyDrive/mbart_datasets/train_dataset_tf"
VAL_DATASET_PATH = "/content/drive/MyDrive/mbart_datasets/val_dataset_tf"

# Saving converted datasets to Google Drive
train_dataset_tf.save_to_disk(TRAIN_DATASET_PATH)
val_dataset_tf.save_to_disk(VAL_DATASET_PATH)
# Out:
# Saving the dataset (0/2 shards):   0%|          | 0/66586 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/672 [00:00<?, ? examples/s]

# %%
from datasets import load_from_disk

train_dataset_tf = load_from_disk("/content/drive/MyDrive/mbart_datasets/train_dataset_tf")
val_dataset_tf = load_from_disk("/content/drive/MyDrive/mbart_datasets/val_dataset_tf")
# Out:
# /usr/local/lib/python3.11/dist-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by promote_options='default'.
#   table = cls._concat_blocks(blocks, axis=0)

# %%
seq2seq_data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

# %% [markdown]
# ## **Model Training**

# %%
class DriveCheckpointCallback(TrainerCallback):
    def __init__(self, max_to_keep=2):
        self.max_to_keep = max_to_keep

    def on_save(self, args, state, control, **kwargs):
        if state.is_world_process_zero:

            checkpoint_path = os.path.join(LOCAL_PATH, f"checkpoint-{state.global_step}")
            drive_checkpoint_path = os.path.join(DRIVE_PATH, f"checkpoint-{state.global_step}")

            os.system(f'cp -r {checkpoint_path} {drive_checkpoint_path}')
            print(f"\nCheckpoint saved to Google Drive: {drive_checkpoint_path}")

            # Removing old checkpoints if exceeding limit
            checkpoints = [d for d in os.listdir(DRIVE_PATH) if d.startswith("checkpoint-")]
            checkpoints = sorted(checkpoints, key=lambda x: int(x.split("-")[-1]))

            if len(checkpoints) > self.max_to_keep:
                for ckpt in checkpoints[:-self.max_to_keep]:
                    path_to_remove = os.path.join(DRIVE_PATH, ckpt)
                    shutil.rmtree(path_to_remove)
                    print(f"Removed old checkpoint: {path_to_remove}")

# %%
# Setting training parameters
training_args = Seq2SeqTrainingArguments(
    output_dir=LOCAL_PATH,  # Saving checkpoints locally
    num_train_epochs=1,
    per_device_train_batch_size=1,
    per_device_eval_batch_size=1,
    eval_strategy='steps',
    save_strategy='steps',
    eval_steps=500,
    save_steps=500,
    logging_steps=100,
    weight_decay=0.01,
    save_total_limit=3,  # Maximum 3 local checkpoints
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    greater_is_better=False,
    fp16=True,
    learning_rate=2e-5,
    optim="adafactor",
    report_to="none",
    push_to_hub=False,
    resume_from_checkpoint=last_checkpoint if last_checkpoint else None
)

# %%
# Creating trainer
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    tokenizer=tokenizer,
    data_collator=seq2seq_data_collator,
    train_dataset=train_dataset_tf,
    eval_dataset=val_dataset_tf,
    callbacks=[DriveCheckpointCallback(max_to_keep=2)]
)
# Out:
# <ipython-input-24-94d17a3961b3>:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value

#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-41500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-40500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-42000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-41000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-42500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-41500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-43000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-42000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-43500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-42500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-44000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-43000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-44500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-43500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-45000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-44000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-45500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-44500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-46000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-45000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-46500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-45500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-47000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-46000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-47500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-46500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-48000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-47000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-48500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-47500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-49000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-48000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-49500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-48500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-50000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-49000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-50500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-49500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-51000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-50000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-51500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-50500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-52000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-51000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-52500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-51500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-53000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-52000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-53500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-52500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-54000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-53000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-54500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-53500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-55000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-54000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-55500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-54500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-56000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-55000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-56500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-55500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-57000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-56000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-57500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-56500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-58000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-57000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-58500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-57500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-59000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-58000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-59500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-58500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-60000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-59000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-60500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-59500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-61000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-60000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-61500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-60500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-62000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-61000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-62500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-61500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-63000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-62000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-63500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-62500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-64000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-63000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-64500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-63500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-65000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-64000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-65500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-64500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-66000
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-65000
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-66500
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-65500
#
# Чекпоинт сохранен в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-66586
# Удален старый чекпоинт: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/checkpoint-66000
# There were missing keys in the checkpoint model loaded: ['model.encoder.embed_tokens.weight', 'model.decoder.embed_tokens.weight', 'lm_head.weight'].
# TrainOutput(global_step=66586, training_loss=0.047764518145445294, metrics={'train_runtime': 73609.3625, 'train_samples_per_second': 0.905, 'train_steps_per_second': 0.905, 'total_flos': 1.443005027277865e+17, 'train_loss': 0.047764518145445294, 'epoch': 1.0})

# %%
final_model_path = os.path.join(DRIVE_PATH, "final_model")
trainer.save_model(final_model_path)
tokenizer.save_pretrained(final_model_path)
print(f"Final model saved to Google Drive: {final_model_path}")
# Out:
# Финальная модель сохранена в Google Drive: /content/drive/MyDrive/mbart_rus_ckt_checkpoints/final_model

# %% [markdown]
# ## **Model Testing**

# %%
import torch

test_prompt = 'Переведи это предложение с русского на чукотский: "Привет, как дела?"'
inputs = tokenizer(test_prompt, return_tensors="pt").input_ids.to("cuda" if torch.cuda.is_available() else "cpu")
outputs = model.generate(inputs, max_length=100)
print("Результат перевода:", tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Результат перевода: Вот перевод на чукотский: "эйвэ, микыри?"

# %% [markdown]
# ## **Uploading model to Hugging Face**

# %%
from huggingface_hub import notebook_login, HfApi
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

from huggingface_hub import login
login()

# Loading trained model (if needed)
# model = AutoModelForSeq2SeqLM.from_pretrained(final_model_path)
# tokenizer = AutoTokenizer.from_pretrained(final_model_path)

# Setting repository information
repo_name = "mbart50-rus-ckt"
organization = "HSE-Chukchi-NLP"

# Creating repository and uploading model
model.push_to_hub(repo_name, organization=organization)
tokenizer.push_to_hub(repo_name, organization=organization)
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# /usr/local/lib/python3.11/dist-packages/transformers/utils/hub.py:741: UserWarning: The `organization` argument is deprecated and will be removed in v5 of Transformers. Set your organization directly in the `repo_id` passed instead (`repo_id={organization}/{model_id}`).
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/2.44G [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/5.17k [00:00<?, ?B/s]
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/HSE-Chukchi-NLP/mbart50-rus-ckt/commit/937f2272291417aa9528b221073fec26d3189914', commit_message='Upload tokenizer', commit_description='', oid='937f2272291417aa9528b221073fec26d3189914', pr_url=None, repo_url=RepoUrl('https://huggingface.co/HSE-Chukchi-NLP/mbart50-rus-ckt', endpoint='https://huggingface.co', repo_type='model', repo_id='HSE-Chukchi-NLP/mbart50-rus-ckt'), pr_revision=None, pr_num=None)
